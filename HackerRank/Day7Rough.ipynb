# %% [markdown]
# # DAY 7 Rough - Linked List

# %%
#Classes and Functions for basic Linked List creation and Operations


class Node:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = None


class LinkedList:
    def __init__(self):
        self.head = None

    def insert_atend(self, val):
        new = Node(val)
        if self.head == None:
            self.head = new
        else:
            t = self.head
            while t.next != None:
                t = t.next
            t.next = new

    def insert_atbeg(self, val):
        new = Node(val)
        if not self.head:
            self.head = new
        else:
            new.next = self.head
            self.head = new

    def insert_atpos_after(self, val, pos):
        c = 0
        temp = self.head
        while temp != None:
            c += 1
            temp = temp.next

        if pos > c or pos <= 0:
            print("invalid input")
            return
        else:
            temp = self.head
            new = Node(val)
            i = 1
            while i < pos:
                temp = temp.next
                i += 1
            new.next = temp.next
            temp.next = new

    def insert_atpos(self, val, pos):
        c = 0
        temp = self.head
        while temp != None:
            c += 1
            temp = temp.next

        if pos > c or pos <= 0:
            print("invalid input")
            return
        else:
            temp = self.head
            new = Node(val)
            i = 1
            while i < pos - 1:
                temp = temp.next
                i += 1
            new.next = temp.next
            temp.next = new

    def delete_atend(self):
        if not self.head:
            print("list is empty")
            return

        if self.head.next == None:
            self.head = None
        else:
            t = self.head
            while t.next.next != None:
                t = t.next
            t.next = None

    def delete_atbeg(self):
        if not self.head:
            print("list is empty")
            return

        if self.head.next == None:
            self.head = None
        else:
            self.head = self.head.next

    def display(self):
        if not self.head:
            print("list is empty")
        else:
            t = self.head
            while t != None:
                print(t.val, "->", end=" ")
                t = t.next

# %%
#10 Reverse a linked list

#HackerRank Default Code
import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node


        self.tail = node

def print_singly_linked_list(node, sep, fptr):
    while node:
        fptr.write(str(node.data))

        node = node.next

        if node:
            fptr.write(sep)



#Function to be written
def reverse(head):
    prev = None
    current = head
    while(current is not None):
        next = current.next
        current.next = prev
        prev = current
        current = next
    return prev



#My function to display linked list
def print_linked_list(head):
    if not head:
        print("list is empty")

    itr = head
    while itr:
        print(itr.data, "->", end= " ")
        itr = itr.next
    print()


#My input and function calling
t = int(input())
for _ in range(t):
    n = int(input())
    sl = SinglyLinkedList()

    for _ in range(n):
        #a = int(input())
        sl.insert_node(a)
    print_linked_list(sl.head)
    print_linked_list(reverse(sl.head))
